# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import requests
import re
import seaborn as sns
from bs4 import BeautifulSoup
from datetime import datetime

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

tvUrl = 'https://www.imdb.com/title/tt0472954/episodes/?season=';

# %%
# get season 1 page for initial show name + season number collection
response = requests.get(tvUrl + "1", headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# all <li> elements with data-testid names of tab-season-entry will be put into a list
# the list will be used to make a range with stripped whitespace, which will be used in an upcoming for loop to iterate through season and episodes
# 1 added to each entry in range since for loop stops at 1 below the max (e.g. range(1,9) will iterate seasons 1 to 8)
seasontabs = soup.find_all('li', {"data-testid" : 'tab-season-entry'})
seasons = []
for tab in seasontabs:
    try:
        season_number = int(tab.text.strip())
        seasons.append(season_number)
    except ValueError:
        print(f"Skipping non-integer season tab: {tab.text.strip()}")

# Now seasons will only contain integer values
seasons = range(1, max(seasons) + 1)

# the show name is located in an h2 element, with the class 'sc-a885edd8-9 dcErWY'. strip the whitespace
show_name = soup.find('h2', class_='sc-a885edd8-9 dcErWY').text.strip()
print(seasons)
print(show_name)
# Out:
# Skipping non-integer season tab: Unknown
# range(1, 19)
# It's Always Sunny in Philadelphia

# %%
def text_to_num(text):
    
    dic = {'K': 1000, 'M': 1000000}

    if text[-1] in dic:
        num, mag = text[:-1], text[-1]
        return int(float(num) * dic[mag])
    else:
        return float(text)

# %%
epnum = re.compile(r'S[0-9]+\.E([0-9]+)')
ratingmatch = re.compile(r'(\d+(?:\.\d+)?)')
votesmatch = re.compile(r'\(([^)]*)\)')

show = []
cumulative_episode_number = 0

for season in seasons:

    # set response using headers from before
    response = requests.get(tvUrl + str(season), headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')

    # find all divs with class kyIRYf, this is the episode info we need
    episodes = soup.find_all('div', class_='kyIRYf')
    
    # for every episode in episodes array we can extract each title
    for episode in episodes:
        # title found in div of class ipfc-title__text, strip to get rid of leading/trailing whitespace
        # this element includes both episode number and title- will be further separated
        title = episode.find('div', class_='ipc-title__text').text.strip()
        # take episode number from title string using regex, convert to int
        episode_number = int(epnum.sub('\\1', title.split(' ∙ ')[0]))
        # update cumulative episode number
        cumulative_episode_number += 1
        # grab title from string, split by dot
        title = title.split(' ∙ ')[1]
        # rating is located in the span of class ipc-rating-star, strip this like the title
        # try / except for future pending season/episode entries with no data: we don't want this and it'll just cause an error.
        try:
            rating = episode.find('span', class_='ipc-rating-star').text.strip()
        except AttributeError:
            break
        # find rating value using regex, first group found, convert to float
        rating_value = re.search(ratingmatch, rating).group(1)
        if '.' in rating_value:
            rating_value = float(rating_value)
        else:
            rating_value = int(rating_value)
        # find vote count from rating string using regex, first group found, convert to num from text
        votes = text_to_num(re.search(votesmatch, rating).group(1))\
        # airdate located in span with class fyhHWhz- strip whitespace, format to proper date notation and convert to datetime
        air_date = datetime.strptime(episode.find('span', class_='fyHWhz').text.strip(), r'%a, %b %d, %Y')
        # description located in div of class ipc-html-content-inner-div, strip whitespace from result
        description = episode.find('div', class_='ipc-html-content-inner-div').text.strip()

        # compile all final found and cleaned data into array, print and append to show (turn show into array of arrays)
        episode_data = [season, episode_number, cumulative_episode_number, title, air_date, rating_value, votes, description]
        print(episode_data)
        show.append(episode_data)
# Out:
# [1, 1, 1, 'The Gang Gets Racist', datetime.datetime(2005, 8, 4, 0, 0), 8.1, 5000, "The guys hire Dee's friend as a promoter for the bar and get more than they bargained for. Charlie seeks black friends to prove he isn't a racist."]
# [1, 2, 2, 'Charlie Wants an Abortion', datetime.datetime(2005, 8, 11, 0, 0), 8.2, 4400, 'In this take on the abortion debate Dennis and Mac go to opposite sides of an abortion rally to pick up women while Charlie deals with an unruly kid he believes to be his son.']
# [1, 3, 3, 'Underage Drinking: A National Concern', datetime.datetime(2005, 8, 16, 0, 0), 8.2, 4300, "The gang turns Paddy's into a safe haven for teens, but things get weird when they all get asked to the local high school prom."]
# [1, 4, 4, 'Charlie Has Cancer', datetime.datetime(2005, 8, 23, 0, 0), 8.0, 4000, 'When Charlie confidentially confides that he has cancer, it leads to a series of instances of the guys manipulating women and one gorgeous transsexual (not a transvestite).']
# [1, 5, 5, 'Gun Fever', datetime.datetime(2005, 8, 30, 0, 0), 7.9, 3800, "When Paddy's gets robbed, the gang decides to purchase a gun with many issues. At the same time Dee is dating a mysterious man which the gang suspects to be the robber."]
# [1, 6, 6, 'The Gang Finds a Dead Guy', datetime.datetime(2005, 9, 6, 0, 0), 8.0, 3700, "A guy dies in Paddy's pub. Dennis and Mac use the guy's death as an excuse to get close to the guy's attractive granddaughter. Meanwhile, Charlie discovers that Dennis and Dee's grandfather was a Nazi."]
# [1, 7, 7, 'Charlie Got Molested', datetime.datetime(2005, 9, 13, 0, 0), 8.4, 4000, "The gang learns that Charlie's former elementary school teacher is on trial for child molestation and they attempt to stage an intervention to get Charlie to admit that he was."]
# [2, 1, 8, 'Charlie Gets Crippled', datetime.datetime(2006, 6, 29, 0, 0), 8.5, 3900, "The gang discovers the perks of being handicapped when Charlie becomes wheel-chair bound after an accident. Dennis and Dee's estranged father returns."]
# [2, 2, 9, 'The Gang Goes Jihad', datetime.datetime(2006, 6, 29, 0, 0), 8.6, 3900, "When half of Paddy's gets bought out by a business developer, the gang seeks revenge. Unfortunately, an ill-timed dog-napping plot, a poorly made video tape, and a flaming bag of poop threaten the gang's chances of getting their property back."]
# [2, 3, 10, 'Dennis and Dee Go on Welfare', datetime.datetime(2006, 7, 6, 0, 0), 9.0, 4600, 'Dennis and Dee quit their jobs and concoct a plan to get welfare benefits so they can pursue their unrealistic goals and dreams.']
# [2, 4, 11, "Mac Bangs Dennis' Mom", datetime.datetime(2006, 7, 6, 0, 0), 9.2, 4900, 'Tensions run high in the gang when Mac courts Dennis and Dee\'s mom and the two organize a stakeout to blackmail Frank and get out of "Charlie work".']
# [2, 5, 12, 'Hundred Dollar Baby', datetime.datetime(2006, 7, 13, 0, 0), 8.7, 4100, 'Inspired by the movie "Million Dollar Baby", Frank teaches Dee to inflict punishment while Dennis and Mac teach Charlie to take punishment. But both fighting careers are derailed by the use of "performance enhancing supplements".']
# [2, 6, 13, 'The Gang Gives Back', datetime.datetime(2006, 7, 20, 0, 0), 8.4, 3500, 'After being arrested for arson, Charlie is sentenced to community service and required to attend AA. Here he makes a discovery that could assist him in his ongoing effort to connect with the Waitress.']
# [2, 7, 14, 'The Gang Exploits a Miracle', datetime.datetime(2006, 7, 27, 0, 0), 7.9, 3300, "Frank tries to cavort the holy crowd when Mac discovers a water stain on Paddy's wall that closely resembles the Virgin Mary."]
# [2, 8, 15, 'The Gang Runs for Office', datetime.datetime(2006, 8, 3, 0, 0), 7.9, 3200, 'The gang discovers that if you run for office, people will pay you to quit. So of course, the gang exploits this and Dennis runs for office. At the same time Frank and Charlie try to stop this, which ends up in a feud.']
# [2, 9, 16, "Charlie Goes America All Over Everybody's Ass", datetime.datetime(2006, 8, 10, 0, 0), 8.2, 3300, "To prove their patriotism, Charlie and Dee try to upstage the local anti-smoking group, while Dennis and Mac turn Paddy's into a bastion of true freedom. But when Frank takes things too far, Paddy's is populated with creeps and lowlifes, and the gang decides they want to live under a totalitarian state."]
# [2, 10, 17, 'Dennis and Dee Get a New Dad', datetime.datetime(2006, 8, 17, 0, 0), 8.5, 3400, "When Dennis and Dee discover their mother has lied to them about Frank being their dad, they get to know their real father. Meanwhile, Mac and Charlie attempt to impress Mac's imprisoned father by becoming hardened criminals."]
# [3, 1, 18, 'The Gang Finds a Dumpster Baby', datetime.datetime(2007, 9, 13, 0, 0), 8.5, 3600, 'Mac and Dee decide to raise a baby they find in the dumpster. Dennis talks some trash while going green and befriending radical environmentalist groups, while Charlie and Frank go dumpster-diving.']
# [3, 2, 19, 'The Gang Gets Invincible', datetime.datetime(2007, 9, 13, 0, 0), 8.7, 3700, "Dennis, Mac, and Dee take part in the Philadelphia Eagles' open tryouts, while Frank drops acid and freaks out when he and Charlie tailgate next to the McPoyles."]
# [3, 3, 20, "Dennis and Dee's Mom Is Dead", datetime.datetime(2007, 9, 20, 0, 0), 8.3, 3200, "After Dennis and Dee's gold-digging mother dies from a botched plastic-surgery operation, Dee and Frank scheme to get their name in the will, while Dennis inherits the house and makes plans for a party mansion."]
# [3, 4, 21, 'The Gang Gets Held Hostage', datetime.datetime(2007, 9, 20, 0, 0), 8.9, 3900, "The McPoyle brothers and sister Margaret take the gang hostage at Paddy's, raising the stakes to a new level in the feud between the two groups."]
# [3, 5, 22, 'The Aluminum Monster vs. Fatty Magoo', datetime.datetime(2007, 9, 27, 0, 0), 7.9, 3100, 'Dee discovers that the biggest loser and fatty from high school is now a successful and thin fashion designer... now making Dee the biggest loser.']
# [3, 6, 23, 'The Gang Solves the North Korea Situation', datetime.datetime(2007, 9, 27, 0, 0), 8.4, 3200, 'As they prepare for the annual Pub Crawl, the gang is horrified to learn that they face competition from a new Korean bar.']
# [3, 7, 24, 'The Gang Sells Out', datetime.datetime(2007, 10, 4, 0, 0), 8.1, 3000, "A corporate chain offers to buy the Paddy's Pub, leaving Dee and Charlie unemployed and forcing them to find jobs at another restaurant, where they abuse their positions and take advantage of the manager, who is Dee's friend."]
# [3, 8, 25, 'Frank Sets Sweet Dee on Fire', datetime.datetime(2007, 10, 4, 0, 0), 8.4, 3200, 'In their quest to become famous, Frank, Charlie, and Mac, search for newsworthy footage to air on public access.']
# [3, 9, 26, "Sweet Dee's Dating a Retarded Person", datetime.datetime(2007, 10, 11, 0, 0), 9.2, 4800, 'While Dennis and Dee try to figure out if the rapper Dee is dating has a mental handicap or not, Charlie, Mac, and Frank try to start their own band without knowledge of how to play musical instruments.']
# [3, 10, 27, 'Mac Is a Serial Killer', datetime.datetime(2007, 10, 18, 0, 0), 9.0, 3900, "After reading that a serial killer is on the loose, the gang notices that Mac is acting shady and decides to find out if he's the man behind the murders."]
# [3, 11, 28, 'Dennis Looks Like a Registered Sex Offender', datetime.datetime(2007, 10, 25, 0, 0), 8.4, 3000, "Dennis is angry because he's being mistaken for a fat guy rather than the sex offender who moved next door to Charlie. Meanwhile, Mac's father is released from prison and he and Mac have some catching up to do."]
# [3, 12, 29, 'The Gang Gets Whacked: Part 1', datetime.datetime(2007, 11, 1, 0, 0), 8.1, 2900, 'After stumbling upon a kilo of cocaine, the gang is forced to pay off a $25,000 debt to the mob. Mac becomes a mob informant, while Frank pimps out Dennis as an escort at the local country club. Charlie stumbles upon an opportunity to sell illegal narcotics.']
# [3, 13, 30, 'The Gang Gets Whacked: Part 2', datetime.datetime(2007, 11, 1, 0, 0), 8.3, 2900, "While paying off their debt to the mob, Charlie and Dee try to find a way to make fake cocaine in order to fool them, while Dennis ranks in thousands of dollars being pimped out at the local country club. Mac realizes his position as a mob informant isn't being utilized to its full potential."]
# [3, 14, 31, 'Bums: Making a Mess All Over the City', datetime.datetime(2007, 11, 15, 0, 0), 8.5, 3100, 'Dee and Mac become Guardian Angels and clean up the streets when a bum starts using the alley behind the bar to masturbate. Meanwhile, Dennis, Charlie, and Frank impersonate police officers in order to get preferential treatment.']
# [3, 15, 32, 'The Gang Dances Their Asses Off', datetime.datetime(2007, 11, 15, 0, 0), 8.9, 3700, "After Charlie accidentally puts Paddy's Pub up for 1st prize in a local dance competition, Frank makes the gang participate in the contest. Here, they form alliances and try to cheat the other contestants, as well as themselves, out of first place."]
# [4, 1, 33, 'Mac and Dennis: Manhunters', datetime.datetime(2008, 9, 18, 0, 0), 8.4, 3100, 'Mac and Dennis pursue the ultimate high of hunting another man by stalking Rickety Cricket, while Dee and Charlie become obsessed with eating human flesh after they come to believe Frank has fed some of it to them.']
# [4, 2, 34, 'The Gang Solves the Gas Crisis', datetime.datetime(2008, 9, 18, 0, 0), 9.1, 4200, 'While Mac, Dennis, and Charlie use their classic setup to sell gallons of gasoline door to door, Frank subjects Dee to a series of torture and mind games when he suspects that Dee is trying to kill him while the two plot to steal their inheritance from Bruce Mathis.']
# [4, 3, 35, "America's Next Top Paddy's Billboard Model Contest", datetime.datetime(2008, 9, 25, 0, 0), 8.3, 2700, 'After buying a billboard, Frank subjects Dennis to a series of humiliating tests in a competition to get on the billboard, while Mac tries to find female subjects willing to go through his own version of a reality show, of sorts.']
# [4, 4, 36, "Mac's Banging the Waitress", datetime.datetime(2008, 9, 25, 0, 0), 8.5, 3000, 'Charlie manipulates Mac and Dennis when he accuses the two of them with sleeping with the coffee shop waitress.']
# [4, 5, 37, 'Mac & Charlie Die: Part 1', datetime.datetime(2008, 10, 2, 0, 0), 9.0, 3400, "After Mac's father is released from prison, Mac and Charlie stage their own deaths to save their lives."]
# [4, 6, 38, 'Mac & Charlie Die: Part 2', datetime.datetime(2008, 10, 2, 0, 0), 8.6, 3000, 'After Mac and Charlie fake their own deaths, the rest of the gang finds unique ways of dealing with the loss.']
# [4, 7, 39, 'Who Pooped the Bed?', datetime.datetime(2008, 10, 9, 0, 0), 8.3, 3400, 'Frank and Charlie find someone has pooped in their bed, leading Mac and Dennis to join them as they attempt to find the culprit.']
# [4, 8, 40, "Paddy's Pub: The Worst Bar in Philadelphia", datetime.datetime(2008, 10, 16, 0, 0), 8.5, 2900, "The gang kidnaps the writer of a review claiming that Paddy's is the worst bar in Philadelphia and tries to force him to change his mind. But things get worse when Dennis and Dee accidentally kidnap the writer's neighbor."]
# [4, 9, 41, 'Dennis Reynolds: An Erotic Life', datetime.datetime(2008, 10, 23, 0, 0), 8.1, 2900, "While Frank and Mac come up with ways to spice up Dennis' erotic memoir, Dee finds that spending time in Charlie's shoes is way more difficult than it seems, and vice-versa."]
# [4, 10, 42, 'Sweet Dee Has a Heart Attack', datetime.datetime(2008, 10, 30, 0, 0), 8.9, 3800, 'After Dee suffers a heart attack, she and Dennis try a healthier lifestyle. Charlie and Mac join the corporate work force to get health insurance.']
# [4, 11, 43, 'The Gang Cracks the Liberty Bell', datetime.datetime(2008, 11, 6, 0, 0), 7.6, 3100, "In order to get Paddy's recognized by the city as a historical landmark, Mac, Dennis, and Charlie flash back to 1776 to tell the tale of the Paddy's crew's involvement in the cracking of the Liberty Bell."]
# [4, 12, 44, 'The Gang Gets Extreme: Home Makeover Edition', datetime.datetime(2008, 11, 13, 0, 0), 8.3, 3000, 'While trying to make their own dreams come true, the gang decides to pay it forward to an unlucky family living in the city only to have their plans backfire on them.']
# [4, 13, 45, 'The Nightman Cometh', datetime.datetime(2008, 11, 20, 0, 0), 9.7, 7900, 'Charlie stages a rock opera based on his song "Nightman," and recruits the rest of the gang to help him with it.']
# [5, 1, 46, 'The Gang Exploits the Mortgage Crisis', datetime.datetime(2009, 9, 17, 0, 0), 8.3, 2900, 'While Frank buys a foreclosed house with intentions of selling it for profit, Mac and Dennis become hot-headed real estate brokers, and Dee takes advantage of a suburban couple looking to hire a surrogate mother.']
# [5, 2, 47, 'The Gang Hits the Road', datetime.datetime(2009, 9, 24, 0, 0), 9.1, 3800, "The gang takes Dee's new subcompact car and a U-haul on the road with the intentions of hitting the Grand Canyon, and Charlie attempts to expand his horizons."]
# [5, 3, 48, 'The Great Recession', datetime.datetime(2009, 10, 1, 0, 0), 8.0, 2700, "Mac and Dennis try to cut back Paddy's expenses by firing Dee and Charlie, and Frank figures out a clever way to keep the bar afloat."]
# [5, 4, 49, 'The Gang Gives Frank an Intervention', datetime.datetime(2009, 10, 8, 0, 0), 8.7, 3300, "After Frank embarrasses himself at the funeral of a deceased relative, Dennis and Dee decide that it's finally time to give him an intervention for his reckless lifestyle."]
# [5, 5, 50, 'The Waitress Is Getting Married', datetime.datetime(2009, 10, 15, 0, 0), 8.8, 3200, 'Dee discovers that the waitress Charlie is obsessed with is getting married to her ex-boyfriend and plots to derail the wedding, while Mac, Frank and Dennis try to get Charlie back on the dating scene.']
# [5, 6, 51, 'The World Series Defense', datetime.datetime(2009, 10, 22, 0, 0), 8.3, 2700, "Fighting a series of traffic tickets, Dennis, along with the rest of the gang, tell the judge about their horrific experiences at Game 5 of the Phillies' world series."]
# [5, 7, 52, 'The Gang Wrestles for the Troops', datetime.datetime(2009, 10, 29, 0, 0), 8.5, 2900, "The gang decides to put on a wrestling show for troops returning home while Dee courts a soldier who doesn't seem like the person she's chatting online with."]
# [5, 8, 53, "Paddy's Pub: Home of the Original Kitten Mittens", datetime.datetime(2009, 11, 5, 0, 0), 8.9, 3300, "The gang attempts to create a merchandising angle for Paddy's when a convention comes to Philly."]
# [5, 9, 54, 'Mac and Dennis Break Up', datetime.datetime(2009, 11, 12, 0, 0), 8.5, 2800, "Taking Dee's advice seriously, Mac and Dennis decide that they're too co-dependent on each other and need to spend time apart. Meanwhile Charlie and Frank help Dee out with a major cat problem in her apartment."]
# [5, 10, 55, 'The D.E.N.N.I.S. System', datetime.datetime(2009, 11, 19, 0, 0), 9.3, 4500, 'Dennis presents his fool-proof plan for picking up chicks, but soon finds that the gang each has their own fool-proof plans for one-upping each other.']
# [5, 11, 56, 'Mac and Charlie Write a Movie', datetime.datetime(2009, 12, 3, 0, 0), 8.1, 2600, 'After Dee gets cast as an extra in the new M. Night Shyamalan movie, Mac and Charlie see a perfect opportunity to pitch their script, while Frank becomes a casting agent for Dennis.']
# [5, 12, 57, 'The Gang Reignites the Rivalry', datetime.datetime(2009, 12, 10, 0, 0), 8.5, 2700, 'Mac, Dennis, and Charlie seek revenge on another bar after their 10-year ban in a local flip-cup tournament is lifted, but find they need serious practice. Dee discovers new skills, and Frank wears tight pants.']
# [6, 1, 58, 'Mac Fights Gay Marriage', datetime.datetime(2010, 9, 16, 0, 0), 7.9, 2700, 'Mac pulls out the big guns to protect the sanctity of marriage, while the rest of the gang reap the rewards of marital bliss.']
# [6, 2, 59, 'Dennis Gets Divorced', datetime.datetime(2010, 9, 23, 0, 0), 7.6, 2500, 'Marital bliss turns to marital business, as the gang experiences the emotional and economic tribulations of divorce.']
# [6, 3, 60, 'The Gang Buys a Boat', datetime.datetime(2010, 9, 30, 0, 0), 8.8, 3300, 'The gang attempts to open themselves up to the adventures of the sea after they purchase their new boat.']
# [6, 4, 61, "Mac's Big Break", datetime.datetime(2010, 10, 7, 0, 0), 8.1, 2600, "After Mac wins a radio contest to score a goal on the Flyers' ice, he and Charlie train for the event - badly, while Dennis and Dee start their own radio program."]
# [6, 5, 62, 'Mac and Charlie: White Trash', datetime.datetime(2010, 10, 14, 0, 0), 8.1, 2600, 'Mac & Charlie attempt to fix up their old pool after getting rejected by a country club, Dennis, Dee, and Frank attempt to gain entry to the club.']
# [6, 6, 63, "Mac's Mom Burns Her House Down", datetime.datetime(2010, 10, 21, 0, 0), 7.6, 2400, "Charlie and Mac set up a truly odd couple after Mac's Mom burns the house down, while Frank discovers the importance of paternal care when Dee falls ill."]
# [6, 7, 64, 'Who Got Dee Pregnant?', datetime.datetime(2010, 10, 28, 0, 0), 9.1, 3500, "The gang gets a real 'scare' after Dee reveals she's pregnant, forcing the guys to recall their last hazy Halloween Party to determine if one of them might be the father."]
# [6, 8, 65, 'The Gang Gets a New Member', datetime.datetime(2010, 11, 4, 0, 0), 7.7, 2500, 'A blast from the past prompts the guys to expand membership, and Dee to re-consider her future.']
# [6, 9, 66, "Dee Reynolds: Shaping America's Youth", datetime.datetime(2010, 11, 11, 0, 0), 8.9, 2900, "Motivated by the drama teacher who inspired her, Dee takes a job as a substitute teacher and exposes her students to the culture of Paddy's with a field trip to see the Gang's take on the Lethal Weapon series: Lethal Weapon 5."]
# [6, 10, 67, 'Charlie Kelly: King of the Rats', datetime.datetime(2010, 11, 18, 0, 0), 8.3, 2600, 'When keeping the basement rodent-free drives Charlie to the brink, the gang decides to put the cynicism aside and throw a surprise party to cheer him up.']
# [6, 11, 68, 'The Gang Gets Stranded in the Woods', datetime.datetime(2010, 12, 2, 0, 0), 8.6, 2700, 'Things go awry as the Gang travels to Atlantic City for a charity benefit. While Frank, Dee and Mac try to survive in the woods, Dennis and Charlie hitch a ride to the city and have the night of their lives.']
# [6, 12, 69, 'Dee Gives Birth', datetime.datetime(2010, 12, 9, 0, 0), 8.5, 2600, "Before Dee's baby arrives, The Gang tries to figure out who is the father by throwing a house party for all her former flings."]
# [6, 13, 70, 'A Very Sunny Christmas', datetime.datetime(2010, 12, 9, 0, 0), 9.2, 5200, 'Dennis and Dee decide to teach Frank a lesson "A Christmas Carol"-style, and Mac and Charlie learn some shocking things about their childhood Christmas traditions.']
# [7, 1, 71, "Frank's Pretty Woman", datetime.datetime(2011, 9, 15, 0, 0), 8.6, 3100, 'When Frank decides to marry a prostitute, the gang tries to uncover her heart of gold.']
# [7, 2, 72, 'The Gang Goes to the Jersey Shore', datetime.datetime(2011, 9, 22, 0, 0), 9.2, 4000, "Dennis and Dee take the gang to their favorite childhood vacation spot, but things aren't quite how they remembered them."]
# [7, 3, 73, "Frank Reynolds' Little Beauties", datetime.datetime(2011, 9, 29, 0, 0), 8.4, 3000, 'The gang accidentally hosts a child beauty pageant.']
# [7, 4, 74, 'Sweet Dee Gets Audited', datetime.datetime(2011, 10, 6, 0, 0), 7.9, 2500, 'Dee faces an IRS audit over her claim that the baby she carried as a surrogate is her dependent, while the guys decide to run the bar in an unemotional, democratic manner rather than their typical method of shouting and personal attacks.']
# [7, 5, 75, "Frank's Brother", datetime.datetime(2011, 10, 13, 0, 0), 6.8, 3000, "When Frank's long lost brother Gino shows up at the bar, the two of them tell the gang about the jazz club they ran in the 1960s and 70s, and how they fell out over Shadynasty, a singer who was the love of both of their lives."]
# [7, 6, 76, 'The Storm of the Century', datetime.datetime(2011, 10, 20, 0, 0), 8.2, 2800, "As a hurricane threatens Philadelphia, Mac, Dennis and Charlie go to a mall to buy supplies and check out the large breasted TV reporter broadcasting from there, while Frank and Dee prepare Paddy's, and its basement bunker, for the storm."]
# [7, 7, 77, 'CharDee MacDennis: The Game of Games', datetime.datetime(2011, 10, 27, 0, 0), 9.2, 4000, 'On a day of ultimate boredom and listlessness, the gang breaks out a homemade board game, created by Mac, Dee, Charlie, and Dennis.']
# [7, 8, 78, 'The ANTI-Social Network', datetime.datetime(2011, 11, 3, 0, 0), 8.3, 2600, "The gang's plan to use Facebook to promote Paddy's goes awry when they become obsessed with tracking down a man who shushed them while they were visiting a trendy new club."]
# [7, 9, 79, 'The Gang Gets Trapped', datetime.datetime(2011, 11, 10, 0, 0), 8.7, 3100, 'Inspired by Indiana Jones, Dennis, Dee, and Frank sneak into a house supposed to contain a rare vase, but become trapped when the owners return home early.']
# [7, 10, 80, 'How Mac Got Fat', datetime.datetime(2011, 11, 17, 0, 0), 7.7, 2500, "During confession, Mac tells a priest how Paddy's sudden spell of success resulted in him becoming fat, and why the rest of the gang is to blame."]
# [7, 11, 81, 'Thunder Gun Express', datetime.datetime(2011, 12, 1, 0, 0), 8.8, 3100, "A presidential visit to Philadelphia threatens to keep the gang from seeing a new action movie, leaving Dennis stuck in traffic, Frank stealing a boat, and Dee and Charlie prowling the city's sewers."]
# [7, 12, 82, 'The High School Reunion', datetime.datetime(2011, 12, 8, 0, 0), 8.2, 2600, 'The gang attends their high school reunion, at which Dee manages to ingratiate herself with the popular crowd, Charlie and Mac get picked on, and Dennis is ignored by everyone.']
# [7, 13, 83, "The High School Reunion Part 2: The Gang's Revenge", datetime.datetime(2011, 12, 15, 0, 0), 8.5, 2700, 'Humiliated by the popular crowd at their high school reunion, the gang attempts to gain revenge, with predictably disastrous results.']
# [8, 1, 84, 'Pop-Pop: The Final Solution', datetime.datetime(2012, 10, 11, 0, 0), 7.8, 2500, "Dennis and Dee's Nazi grandfather is wasting away in a hospital, and it's their choice whether to pull the plug or not. Meanwhile, Charlie and Mac go crazy trying to find a dog painting they think has a lot of value."]
# [8, 2, 85, 'The Gang Recycles Their Trash', datetime.datetime(2012, 10, 18, 0, 0), 8.2, 2300, "While the city of Philadelphia's garbage men are on strike, Dennis, Mac, and Charlie decide to start a trash pick up business. And while being a big success, they must find out where to put this newly picked up trash."]
# [8, 3, 86, 'The Maureen Ponderosa Wedding Massacre', datetime.datetime(2012, 10, 25, 0, 0), 8.7, 3100, 'The gang are the prime suspects for the McPoyle-Ponderosa wedding massacre.']
# [8, 4, 87, 'Charlie and Dee Find Love', datetime.datetime(2012, 11, 1, 0, 0), 8.9, 3300, 'After invading the world of the wealthy, Charlie and Dee find romance. Not to be left out, Dennis, Frank and Mac try to get in on the action.']
# [8, 5, 88, 'The Gang Gets Analyzed', datetime.datetime(2012, 11, 8, 0, 0), 9.0, 3300, "When Dee gets asked by her therapist to bring in her so called 'issues,' Dee brings in the whole gang. And since they have all been called in, they have their own one on one therapy sessions, while many issues arise."]
# [8, 6, 89, "Charlie's Mom Has Cancer", datetime.datetime(2012, 11, 15, 0, 0), 7.7, 2400, "Charlie's Mom tells him she has cancer. The gang tries to help her out, each in their own way. Meanwhile, Frank thinks his mind may be slipping."]
# [8, 7, 90, "Frank's Back in Business", datetime.datetime(2012, 11, 29, 0, 0), 8.1, 2400, "Under threat of a hostile takeover, the board of Frank's old company calls him back to run the company. As before, Frank maximizes the company's product: money. Dennis, Mac and Dee find Phillies VIP tickets and find themselves in a business deal of their own."]
# [8, 8, 91, 'Charlie Rules the World', datetime.datetime(2012, 12, 6, 0, 0), 8.3, 2500, 'The gang starts playing an online video game and Charlie becomes obsessed with becoming the best player in the game. Meanwhile, Dennis is upset everyone else is playing the game all the time and not out enjoying the real world.']
# [8, 9, 92, 'The Gang Dines Out', datetime.datetime(2012, 12, 13, 0, 0), 9.0, 3300, 'The gang turns up at the same restaurant for dinner at three different tables. They pretend not to notice they noticed they are noticing each other. Then the one-upmanship begins.']
# [8, 10, 93, 'Reynolds vs. Reynolds: The Cereal Defense', datetime.datetime(2012, 12, 20, 0, 0), 9.0, 3200, "When Frank accidentally hits Dennis's car while Dennis is eating cereal, Frank and Dennis go to the Paddy's Pub court to face off on who will pay for the damages."]
# [9, 1, 94, 'The Gang Broke Dee', datetime.datetime(2013, 9, 4, 0, 0), 8.8, 3300, 'Dee embraces the desperate, self-loathing qualities the guys have beaten her into over the years, sending her stand-up comedy to unexpected places.']
# [9, 2, 95, 'Gun Fever Too: Still Hot', datetime.datetime(2013, 9, 11, 0, 0), 8.2, 2500, 'After Frank appears on TV advocating gun ownership, the rest of the gang takes a look at the ownership process and alternatives to find common ground.']
# [9, 3, 96, 'The Gang Tries Desperately to Win an Award', datetime.datetime(2013, 9, 18, 0, 0), 9.2, 4200, "The gang attempts to win the award for Philidelphia's Best Bar."]
# [9, 4, 97, 'Mac and Dennis Buy a Timeshare', datetime.datetime(2013, 9, 25, 0, 0), 8.0, 2500, 'After making some very questionable investment choices, the gang try to dump their losses on Ben The Soldier while they look for the man who is pulling their strings.']
# [9, 5, 98, 'Mac Day', datetime.datetime(2013, 10, 2, 0, 0), 8.6, 2800, "Each member of the gang gets one day to do whatever they want while the rest of the gang must participate. This is Mac's day."]
# [9, 6, 99, 'The Gang Saves the Day', datetime.datetime(2013, 10, 9, 0, 0), 9.0, 3500, 'When the gang find themselves in the middle of a robbery at a local convenience store, they all imagine what will happen next.']
# [9, 7, 100, 'The Gang Gets Quarantined', datetime.datetime(2013, 10, 16, 0, 0), 8.7, 2900, "When a severe flu outbreak sweeps Philadelphia the gang voluntarily quarantine themselves inside of Paddy's."]
# [9, 8, 101, 'Flowers for Charlie', datetime.datetime(2013, 10, 23, 0, 0), 8.7, 3100, "When an experiment successfully multiplies Charlie's intellect and takes him away from the bar, the rest of the gang find themselves struggling to complete the menial 'Charlie Work' that has kept the bar running for so long."]
# [9, 9, 102, 'The Gang Makes Lethal Weapon 6', datetime.datetime(2013, 10, 30, 0, 0), 8.0, 2300, 'After creative differences over what constitutes tasteful nudity cause Frank to pull his money out of Lethal Weapon 6 during filming, Mac, Dennis, and Charlie screen their rough footage for investors in hopes of raising enough capital to finish the production of their latest masterpiece.']
# [9, 10, 103, 'The Gang Squashes Their Beefs', datetime.datetime(2013, 11, 6, 0, 0), 8.2, 2500, "When some bad blood with old foes compromises their ideal Thanksgiving, the gang decides to make amends by breaking bread with those they've hurt."]
# [10, 1, 104, 'The Gang Beats Boggs', datetime.datetime(2015, 1, 14, 0, 0), 8.7, 3300, 'The gang try to beat a record set by Wade Boggs of 70 beers on a cross-country flight.']
# [10, 2, 105, 'The Gang Group Dates', datetime.datetime(2015, 1, 21, 0, 0), 8.7, 2900, "The gang decides to start a group dating service at Paddy's."]
# [10, 3, 106, 'Psycho Pete Returns', datetime.datetime(2015, 1, 28, 0, 0), 7.5, 2500, 'Mac and Charlie are excited for the return of their old high school friend, Pete, while the rest of the gang fears for his psychotic behavior.']
# [10, 4, 107, 'Charlie Work', datetime.datetime(2015, 2, 4, 0, 0), 9.8, 10000, "Charlie is determined to make sure Paddy's Pub passes its health inspection."]
# [10, 5, 108, 'The Gang Spies Like U.S.', datetime.datetime(2015, 2, 11, 0, 0), 8.2, 2400, 'When Dennis and Mac send Dee to spy on the fish factory across the street, Frank and Charlie become suspicious themselves.']
# [10, 6, 109, 'The Gang Misses the Boat', datetime.datetime(2015, 2, 18, 0, 0), 8.8, 2900, 'The gang decides to spend some time apart in order to find out who they really are.']
# [10, 7, 110, 'Mac Kills His Dad', datetime.datetime(2015, 2, 25, 0, 0), 7.9, 2200, "After Mac's dad is suspected of murder, Mac sets out to clear his father of any wrong doing."]
# [10, 8, 111, 'The Gang Goes on Family Fight', datetime.datetime(2015, 3, 4, 0, 0), 9.0, 3300, 'When the gang appears on a nationally broadcast game show, Dennis does his best to make a good impression.']
# [10, 9, 112, 'Frank Retires', datetime.datetime(2015, 3, 11, 0, 0), 8.0, 2200, 'When Frank decides to retire, the gang fights over who gets to be in charge of the bar.']
# [10, 10, 113, 'Ass Kickers United: Mac and Charlie Join a Cult', datetime.datetime(2015, 3, 18, 0, 0), 7.5, 2300, 'Mac and Charlie become brainwashed by a cult.']
# [11, 1, 114, 'Chardee MacDennis 2: Electric Boogaloo', datetime.datetime(2016, 1, 6, 0, 0), 8.5, 2900, 'The foursome demonstrate Chardee MacDennis for an interested board game executive.']
# [11, 2, 115, 'Frank Falls Out the Window', datetime.datetime(2016, 1, 13, 0, 0), 8.0, 2500, "After falling out of the window, Frank thinks that it's 2006; the other three see this as a do-over."]
# [11, 3, 116, 'The Gang Hits the Slopes', datetime.datetime(2016, 1, 20, 0, 0), 8.5, 3300, 'Dennis and Frank square off against Dee and Mac for control of the mountain, while Charlie learns that the slopes have their own set of rules.']
# [11, 4, 117, 'Dee Made a Smut Film', datetime.datetime(2016, 1, 27, 0, 0), 7.5, 2400, "The Gang debates modern art after seeing Dee in a smut film; Mac and Charlie enlist the help of Frank and Cricket in order to prove that modern art is worthless, whilst Dee and Dennis adapt his erotic memoirs to prove that it isn't."]
# [11, 5, 118, 'Mac & Dennis Move to the Suburbs', datetime.datetime(2016, 2, 3, 0, 0), 9.4, 5100, 'Dennis and Mac head to the suburbs for cheap rent and open spaces but quickly find out that they are meant for city life.']
# [11, 6, 119, 'Being Frank', datetime.datetime(2016, 2, 10, 0, 0), 8.3, 3100, "A day in the life of Frank Reynolds as he tries to keep up with the gang's newest scheme."]
# [11, 7, 120, 'McPoyle vs. Ponderosa: The Trial of the Century', datetime.datetime(2016, 2, 17, 0, 0), 8.6, 2900, 'Liam McPoyle teams up with the lawyer to sue Bill Ponderosa for his lost eye; old grievances resurface.']
# [11, 8, 121, 'Charlie Catches a Leprechaun', datetime.datetime(2016, 2, 24, 0, 0), 8.5, 2600, "Dennis tries to create an innovative mobile Paddy's pub experience but runs into trouble when customers refuse to cooperate, while Charlie and Mac attempt to catch a thieving leprechaun."]
# [11, 9, 122, 'The Gang Goes to Hell', datetime.datetime(2016, 3, 2, 0, 0), 8.4, 2500, "The gang board a Christian cruise liner upon Mac's request, to soon find out that it does not cater to their sinful ways."]
# [11, 10, 123, 'The Gang Goes to Hell: Part Two', datetime.datetime(2016, 3, 9, 0, 0), 8.4, 2500, 'The gang gets real with one another in the face of death.']
# [12, 1, 124, 'The Gang Turns Black', datetime.datetime(2017, 1, 4, 0, 0), 8.5, 4600, "After an electric heating blanket shorts out while the gang watches The Wiz, they look in the mirror and realize they've turned black. They have to work out how to get back to being themselves by going through all the classic body switching shenanigans."]
# [12, 2, 125, 'The Gang Goes to a Water Park', datetime.datetime(2017, 1, 11, 0, 0), 9.5, 5400, 'The gang takes a trip to a local waterpark, ripe with personal agendas and ulterior motives. Dennis feeds off his mantra of "the park provides" and takes on a protégé. Frank and Charlie are determined to ride every ride by any means necessary and Mac and Dee get stuck in a tube slide for most of the day.']
# [12, 3, 126, 'Old Lady House: A Situation Comedy', datetime.datetime(2017, 1, 18, 0, 0), 8.5, 3000, "The gang installs spy cameras in Mrs. Kelly and Mrs. Mac's house, to soon realise that the footage would make for a successful sitcom."]
# [12, 4, 127, 'Wolf Cola: A Public Relations Nightmare', datetime.datetime(2017, 1, 25, 0, 0), 8.0, 2500, 'Franks Fluids LLC is in big trouble after a news segment shows Wolf Cola has become the official drink of Boko Haram.']
# [12, 5, 128, 'Making Dennis Reynolds a Murderer', datetime.datetime(2017, 2, 1, 0, 0), 8.6, 3000, 'An episode filmed in the true crime style of Making a Murderer and The Jinx which begins with 911 call: A cat-woman formerly known as Maureen Ponderosa has been found dead in an alley and Dennis is the prime suspect.']
# [12, 6, 129, 'Hero or Hate Crime?', datetime.datetime(2017, 2, 8, 0, 0), 9.4, 4600, "The gang go to a professional arbitrator to decide who's the rightful owner of a scratch-off lottery ticket."]
# [12, 7, 130, 'PTSDee', datetime.datetime(2017, 2, 15, 0, 0), 8.6, 2800, 'After finding out she\'s a male stripper\'s "rock bottom," Dee goes on a mission to prove she\'s the best thing that ever happened to him. Dennis takes over for the stripper with the help of his bag boy, Charlie. Meanwhile, Mac and Frank get sucked into a VR war game that causes Mac to develop his own case of PTSD.']
# [12, 8, 131, 'The Gang Tends Bar', datetime.datetime(2017, 2, 22, 0, 0), 8.1, 2300, "It's Valentine's Day and Paddy's is packed with customers. Dennis implores the gang to do one day of actual work but everyone else is distracted by a mystery crate Cricket spotted in the alley. Eventually, the gang becomes convinced Dennis really wants them to work on their relationships and everyone shares their grievances without much resolution."]
# [12, 9, 132, "A Cricket's Tale", datetime.datetime(2017, 3, 1, 0, 0), 7.2, 2500, 'A typical day in the life of Cricket, with possible redemption when his family intervenes.']
# [12, 10, 133, "Dennis' Double Life", datetime.datetime(2017, 3, 8, 0, 0), 8.5, 2600, 'Dennis reveals that he has a baby from his layover time in North Dakota and everyone offers solutions to the problem, but in the end, Dennis must decide which life to continue to lead.']
# [13, 1, 134, "The Gang Makes Paddy's Great Again", datetime.datetime(2018, 9, 5, 0, 0), 7.6, 3000, 'Meet Cindy, the new, ethnically diverse female member of the gang who can successfully pull off scams. Everything is working until Mac introduces a new member: a life-like sex doll that looks exactly like Dennis.']
# [13, 2, 135, 'The Gang Escapes', datetime.datetime(2018, 9, 12, 0, 0), 8.0, 2700, 'When Mac and Dennis are looking to boost productivity around their apartment, Sweet Dee hires an "escape room experience" service.']
# [13, 3, 136, 'The Gang Beats Boggs: Ladies Reboot', datetime.datetime(2018, 9, 19, 0, 0), 6.6, 3800, "For a chance to get one over on the guys, Dee joins an all-female flight with Artemis, the Waitress, Charlie's mom, and Mac's mom to beat the Wade Boggs 'drinking whilst on a flight' record."]
# [13, 4, 137, "Time's Up for the Gang", datetime.datetime(2018, 9, 26, 0, 0), 9.2, 3800, "Paddy's has been put on a list of bars that are sexually hostile to women, so the gang must attend a sexual-harassment seminar in order to get off the list."]
# [13, 5, 138, 'The Gang Gets New Wheels', datetime.datetime(2018, 10, 3, 0, 0), 8.9, 3200, 'Dee gets in with a group of cool, rich housewives. Dennis hits it off with some everyday blue-collar bros. Frank struggles to renew his license, and Charlie and Mac deal with a new generation of bicycle bullies.']
# [13, 6, 139, 'The Gang Solves the Bathroom Problem', datetime.datetime(2018, 10, 10, 0, 0), 8.3, 2700, "Jimmy Buffett is in town and the positive vibes are alive at the bar. However, when Mac comes out of the women's bathroom, no one can leave until the bathroom situation is solved."]
# [13, 7, 140, 'The Gang Does a Clip Show', datetime.datetime(2018, 10, 17, 0, 0), 7.5, 2800, "With nothing to do while their phones update to the latest software, the gang decides to reminisce on old times; as everyone misremembers events from their past, the gang's current reality becomes altered."]
# [13, 8, 141, "Charlie's Home Alone", datetime.datetime(2018, 10, 24, 0, 0), 6.8, 2800, "It's the weekend of Super Bowl LII from Charlie's perspective. While Charlie searches the back office, Cricket steals the suit leaving Charlie home alone to defend himself."]
# [13, 9, 142, 'The Gang Wins the Big Game', datetime.datetime(2018, 10, 31, 0, 0), 7.1, 2500, "It's the most important weekend of their lives and Frank has treated the gang and a crew of their ragtag hangers-on with tickets to see the Eagles in the Super Bowl!"]
# [13, 10, 143, 'Mac Finds His Pride', datetime.datetime(2018, 11, 7, 0, 0), 8.6, 5700, "Frank tries to recruit Mac for the gang's float for the Gay Pride Parade; Frank comes to the realization that Mac will never be secure with his sexual identity unless he comes out to his father."]
# [14, 1, 144, 'The Gang Gets Romantic', datetime.datetime(2019, 9, 25, 0, 0), 7.9, 2500, "Mac concocts a scheme to attract single women to rent Dennis's bedroom while Frank and Charlie make similar plans to draw in young European coeds, but neither ad attracts their intended target."]
# [14, 2, 145, 'Thunder Gun 4: Maximum Cool', datetime.datetime(2019, 10, 2, 0, 0), 7.8, 2300, 'The Gang finds themselves in the middle of a focus group after a screening of Thunder Gun 4: Maximum Cool.']
# [14, 3, 146, 'Dee Day', datetime.datetime(2019, 10, 9, 0, 0), 8.3, 2200, 'The guys are in the final preparation stage for an unknown scheme when Dee excitedly enters to inform them that today is "Dee Day" and the guys must do everything she wants without complaint.']
# [14, 4, 147, 'The Gang Chokes', datetime.datetime(2019, 10, 16, 0, 0), 8.0, 2100, 'Annoyed that the Gang failed to react as he nearly choked to death on an appetizer, Frank decides the Waiter, his savior, is the only person who has his back.']
# [14, 5, 148, 'The Gang Texts', datetime.datetime(2019, 10, 23, 0, 0), 8.0, 2300, 'During their trip to the Philadelphia Zoo, Mac sets up a group text for The Gang that leads to confusion.']
# [14, 6, 149, 'The Janitor Always Mops Twice', datetime.datetime(2019, 10, 30, 0, 0), 8.5, 2700, 'In the black-and-white noir world of his memory, Charlie navigates the seedy underbelly of Philadelphia as Frank has been "diarrhea poisoned," and it\'s up to Charlie to clean up the mess.']
# [14, 7, 150, 'The Gang Solves Global Warming', datetime.datetime(2019, 11, 6, 0, 0), 8.0, 2000, "As a record-breaking heat wave overtakes Philly, the Gang plans to profit from global warming by pumping up the A/C so people will congregate at Paddy's and save energy at home."]
# [14, 8, 151, "Paddy's Has a Jumper", datetime.datetime(2019, 11, 13, 0, 0), 8.3, 2000, "While a suicidal man threatens to jump off Paddy's pub, the gang wonders whether they should help the poor man or let him fall to his death."]
# [14, 9, 152, "A Woman's Right to Chop", datetime.datetime(2019, 11, 20, 0, 0), 7.9, 1800, "When a trendy new hair salon opens up right next door to Paddy's, Dennis and Frank go on the offensive to stop women from cutting off their hair. Meanwhile, Mac is reunited with his childhood dog Poppins."]
# [14, 10, 153, 'Waiting for Big Mo', datetime.datetime(2019, 11, 20, 0, 0), 7.6, 2000, 'Dennis and Charlie stand guard at the entrance to their laser tag base waiting to ambush the legendary "Big Mo," but Dennis begins to ponder the reasons they play laser tag and if their pursuit of a victory is worth their effort.']
# [15, 1, 154, '2020: A Year In Review', datetime.datetime(2021, 12, 1, 0, 0), 8.0, 2600, 'The gang looks back on 2020 to justify their numerous PPP loans as they contributed to the chaos of the past political year way more than anyone could have imagined.']
# [15, 2, 155, 'The Gang Makes Lethal Weapon 7', datetime.datetime(2021, 12, 1, 0, 0), 7.8, 2200, 'Upon discovering that their self-made Lethal Weapon sequels have been pulled from the local library, the Gang decides to address their political incorrectness by making another film: Lethal Weapon 7.']
# [15, 3, 156, 'The Gang Buys a Roller Rink', datetime.datetime(2021, 12, 8, 0, 0), 7.6, 2000, "In the past, an innocent Dennis learns the horrifying details of Frank's business, a truly sweet Dee is excited to head off for Hollywood, while Charlie and Mac's jobs at the roller rink are in jeopardy."]
# [15, 4, 157, 'The Gang Replaces Dee With a Monkey', datetime.datetime(2021, 12, 8, 0, 0), 8.1, 1800, "When the Gang suspects Dee is menopausal, they scramble to find a new employee for Paddy's Pub; Dee decides to put her acting career on hold in order to mentor young actors."]
# [15, 5, 158, 'The Gang Goes to Ireland', datetime.datetime(2021, 12, 15, 0, 0), 8.1, 1800, 'Dennis ends up helping Frank with some of his business\'s dirty work. Mac and Charlie learn about their Irish heritage while Dee rushes to the set of an Irish soap opera and she will play an "Obnoxious American MILF.']
# [15, 6, 159, "The Gang's Still in Ireland", datetime.datetime(2021, 12, 15, 0, 0), 8.5, 1900, "Dennis and Dee explore their new accommodations in the countryside; Frank accompanies Charlie to find the truth about Charlie's Irish childhood pen pal; Mac has an identity crisis and decides to join the seminary."]
# [15, 7, 160, 'Dee Sinks in a Bog', datetime.datetime(2021, 12, 22, 0, 0), 8.0, 1600, "Mac spends a day at the seminary to truly understand what it takes to become a priest; Dennis and Frank plan an elaborate trap to humiliate Charlie's pen pal; Dee prepares for a date with an Irish doctor; Charlie bonds with his pen pal."]
# [15, 8, 161, 'The Gang Carries a Corpse Up a Mountain', datetime.datetime(2021, 12, 22, 0, 0), 8.8, 2300, 'The Gang attempts to ascend a mountain in order for Charlie to fulfill an old and mysterious Irish burial tradition; one by one, the Gang backs out until Charlie is left to honor the dead body alone.']
# [16, 1, 162, 'The Gang Inflates', datetime.datetime(2023, 6, 7, 0, 0), 8.2, 2000, "Dennis and Mac get into inflatable furniture to deal with the economy's inflation, while Dee tries to find a place to crash after being evicted by her greedy landlord and Charlie wants to pitch Frank his crypto/online investment idea."]
# [16, 2, 163, 'Frank Shoots Every Member of the Gang', datetime.datetime(2023, 6, 7, 0, 0), 7.8, 1800, "After Frank shoots Dennis and Dee, they resolve to take Frank's gun away; Mac and Charlie go on a road trip with their moms to get their inheritances."]
# [16, 3, 164, 'The Gang Gets Cursed', datetime.datetime(2023, 6, 14, 0, 0), 7.6, 1500, "A series of bad omens leads the gang to believe they are all cursed; they set off to undo the curses and make amends to those they've wronged; Mac meets Chase Utley and invites him for a catch."]
# [16, 4, 165, 'Frank vs. Russia', datetime.datetime(2023, 6, 21, 0, 0), 8.7, 2100, 'Charlie cheers on Frank at a local chess tournament against a Russian grand master; Dennis helps Mac and Dee find boyfriends.']
# [16, 5, 166, 'Celebrity Booze: The Ultimate Cash Grab', datetime.datetime(2023, 6, 28, 0, 0), 8.0, 1600, "When news spreads of Bryan Cranston and Aaron Paul's visit to Philadelphia to promote their Dos Hombres mezcal brand, the guys decide to pitch them their own liquor; the gang takes to the skies to get a taste of the glamorous high life."]
# [16, 6, 167, "Risk E. Rat's Pizza & Amusement Center", datetime.datetime(2023, 7, 5, 0, 0), 7.8, 1400, 'The Gang goes to "Risk E. Rat\'s" only to find all the riskiness has been systematically replaced with safety and overcautiousness. Dennis and Charlie try to find the old ride with the animatronic boobs. Dee takes Frank on a scavenger hunt.']
# [16, 7, 168, 'The Gang Goes Bowling', datetime.datetime(2023, 7, 12, 0, 0), 8.7, 1600, "The guys crash Dee's bowling league night and compete in a Battle of the Sexes at a bowling alley owned by the McPoyles."]
# [16, 8, 169, 'Dennis Takes a Mental Health Day', datetime.datetime(2023, 7, 19, 0, 0), 9.2, 2200, 'After a physical reveals Dennis has high blood pressure, he decides to take a day away from The Gang to de-stress at the beach. But life has other plans, and his day spirals into a string of mishaps until he can no longer contain his rage.']

# %%
show = pd.DataFrame(show,columns=["season", "episode_number", "cumulative_episode_number", "title", "air_date", "rating_value", "votes", "description"])
show.head(20)
# Out:
#     season  episode_number  cumulative_episode_number  \
# 0        1               1                          1
# 1        1               2                          2
# 2        1               3                          3
# 3        1               4                          4
# 4        1               5                          5
# 5        1               6                          6
# 6        1               7                          7
# 7        2               1                          8
# 8        2               2                          9
# 9        2               3                         10
# 10       2               4                         11
# 11       2               5                         12
# 12       2               6                         13
# 13       2               7                         14
# 14       2               8                         15
# 15       2               9                         16
# 16       2              10                         17
# 17       3               1                         18
# 18       3               2                         19
# 19       3               3                         20
#
#                                             title   air_date  rating_value  \
# 0                            The Gang Gets Racist 2005-08-04           8.1
# 1                       Charlie Wants an Abortion 2005-08-11           8.2
# 2           Underage Drinking: A National Concern 2005-08-16           8.2
# 3                              Charlie Has Cancer 2005-08-23           8.0
# 4                                       Gun Fever 2005-08-30           7.9
# 5                       The Gang Finds a Dead Guy 2005-09-06           8.0
# 6                            Charlie Got Molested 2005-09-13           8.4
# 7                           Charlie Gets Crippled 2006-06-29           8.5
# 8                             The Gang Goes Jihad 2006-06-29           8.6
# 9                    Dennis and Dee Go on Welfare 2006-07-06           9.0
# 10                          Mac Bangs Dennis' Mom 2006-07-06           9.2
# 11                            Hundred Dollar Baby 2006-07-13           8.7
# 12                            The Gang Gives Back 2006-07-20           8.4
# 13                    The Gang Exploits a Miracle 2006-07-27           7.9
# 14                       The Gang Runs for Office 2006-08-03           7.9
# 15  Charlie Goes America All Over Everybody's Ass 2006-08-10           8.2
# 16                   Dennis and Dee Get a New Dad 2006-08-17           8.5
# 17                 The Gang Finds a Dumpster Baby 2007-09-13           8.5
# 18                       The Gang Gets Invincible 2007-09-13           8.7
# 19                   Dennis and Dee's Mom Is Dead 2007-09-20           8.3
#
#     votes                                        description
# 0    5000  The guys hire Dee's friend as a promoter for t...
# 1    4400  In this take on the abortion debate Dennis and...
# 2    4300  The gang turns Paddy's into a safe haven for t...
# 3    4000  When Charlie confidentially confides that he h...
# 4    3800  When Paddy's gets robbed, the gang decides to ...
# 5    3700  A guy dies in Paddy's pub. Dennis and Mac use ...
# 6    4000  The gang learns that Charlie's former elementa...
# 7    3900  The gang discovers the perks of being handicap...
# 8    3900  When half of Paddy's gets bought out by a busi...
# 9    4600  Dennis and Dee quit their jobs and concoct a p...
# 10   4900  Tensions run high in the gang when Mac courts ...
# 11   4100  Inspired by the movie "Million Dollar Baby", F...
# 12   3500  After being arrested for arson, Charlie is sen...
# 13   3300  Frank tries to cavort the holy crowd when Mac ...
# 14   3200  The gang discovers that if you run for office,...
# 15   3300  To prove their patriotism, Charlie and Dee try...
# 16   3400  When Dennis and Dee discover their mother has ...
# 17   3600  Mac and Dee decide to raise a baby they find i...
# 18   3700  Dennis, Mac, and Dee take part in the Philadel...
# 19   3200  After Dennis and Dee's gold-digging mother die...

# %%
plt.figure(figsize=(15,6))
plt.grid(color='grey', linestyle='--', linewidth=0.5)

max_rating = show['rating_value'].max()
min_rating = show['rating_value'].min()

plt.axhline(max_rating, color='green', label='Max', linewidth=0.8, linestyle='--')
plt.axhline(min_rating, color='red', label='Min', linewidth=0.8, linestyle='--')
plt.axhline(show['rating_value'].median(), color='blue', label='Median', linewidth=0.8, linestyle='--')
plt.axhline(show['rating_value'].mean(), color='black', label='Average', linewidth=0.8, linestyle='--')
sns.lineplot(data=show, x='cumulative_episode_number', y='rating_value', color='orange')
sns.scatterplot(data=show, x='cumulative_episode_number', y='rating_value', color='orange')
plt.xlim(0,show['cumulative_episode_number'].max()+2)

plt.xlabel("Episode Number")
plt.ylabel("Rating")

plt.title(f"IMDb Rating Trend for {show_name}")
plt.legend(loc='upper left', bbox_to_anchor=(1,1))

print("Average: ", show['rating_value'].mean())
print("Max: ", max_rating, ", episode(s): ", show[show['rating_value'] == max_rating]['title'].tolist())
print("Min: ", min_rating, ", episode(s): ", show[show['rating_value'] == min_rating]['title'].tolist())
print("Median: ", show['rating_value'].median())

directory_path = f'data/{show_name}/figures'

# Create the directory if it does not exist
if not os.path.exists(directory_path):
    os.makedirs(directory_path)

plt.savefig(f'data/{show_name}/figures/linegraph.png', dpi=300, bbox_inches='tight')
# Out:
# Average:  8.363905325443787
# Max:  9.8 , episode(s):  ['Charlie Work']
# Min:  6.6 , episode(s):  ['The Gang Beats Boggs: Ladies Reboot']
# Median:  8.4

# %%
pivot_shows = show.pivot_table(index="season", columns="episode_number", values="rating_value")

plt.figure(figsize=(10,9))
ax = sns.heatmap(pivot_shows, annot=True)

ax.set_xlabel('Episode Number')
ax.set_ylabel('Season')

# Set the main title
ax.set_title(f'Average Ratings per {show_name} Episode by Season')

ax.tick_params(axis='both', which='both', length=0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0) 
ax.set_yticklabels(ax.get_yticklabels(), rotation=0)

directory_path = f'data/{show_name}/figures'

# Create the directory if it does not exist
if not os.path.exists(directory_path):
    os.makedirs(directory_path)

plt.savefig(f'data/{show_name}/figures/heatmap.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
show.to_csv(f'data/{show_name}/{show_name}-imdbdata.csv')
